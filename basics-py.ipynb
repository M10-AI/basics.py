# %% [markdown]
# <a href="https://www.kaggle.com/code/m10artin/basics-py?scriptVersionId=206011758" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Basic python syntax & exercises
#
# ### Block A
#
# - functions pt.1 (print, '', "", """""" )
# - variables
# - datatypes
# - operators
# - f-string, string methods
# - if else statements
# - Indexing & slicing
#
#
# ### Block B
# - functions pt.2 (kwargs, recursion)
# - Range, for, while loop, continue & break
#
#
# ### Block C
#
# - list comprehension
# - Filhantering, csv, json
# - Try,except
# - Streamlit
#
# ### Block D
# - Calculator
# - Pikachu lab

# %%
variabel1 = 1 #integer
variabel2 = 1.5  #floats
variabel3 = "strängar" #strings
variabel4 = True #Booleans


name = 2
var = "My name is {name}"

#print(var)

names = ["Sagal", "Lana", "Qasim", "Shariq", "Johan", "Joseph"] #lista

# for name in names:
#     print(name)
    
#print(names[0:4:2]) #[början, slutet, hopp<]
#print(names[:4])
#print(names[::-1])

# %% [markdown]
# # Exercise 1:
# You found a T-shirt which costs 90 SEK, and as a regular customer you get 3% discount. How much would the T-shirt cost for you?
#
# Write down the computation by first definining two variables price and discount, and then storing the result in the variable my_price. At the end print the result.

# %%
t_shirt = 90
discount = 0.97

my_price = t_shirt * discount

print(my_price)
# Out:
# 87.3

# %% [markdown]
# # Exercise 2:
#
# You’re renting a cabin for a weekend getaway. The cabin costs 800 SEK per night. As a loyalty member, you receive a 12% discount on the first night and a 7% discount on the second night.
# The third night is free! How much will you pay in total for a 3-night stay?
#
# Write down the computation by first defining three variables: night1_price, night2_price, and night3_price (for each night's original price). Then apply the respective discounts, and finally add the cost of the third night. Store the total cost in the variable total_cost and print the result.

# %%
night_price = 800
discount1 = 0.88
discount2 = 0.93


night1_price = night_price * discount1
night2_price = night1_price * discount2
night3_price = 0

total = night2_price + night1_price + night3_price

print(total)
# Out:
# 1358.72

# %% [markdown]
# # Exercise 3:
#
# You found a deal on a set of three books. The first book costs 120 SEK, the second costs 150 SEK, and the third costs 180 SEK.
# Since you're purchasing a set, you get a 10% discount on the most expensive book.  However, you also receive an additional discount of 5% on the total price of all three books. How much will you pay in total?
#
# Write down the computation by first defining three variables. Then, apply the 10% discount, add up all the prices, apply the additional 5% discount on the subtotal, and store the final total in a variable called final_price. Print the result.

# %%
print("Welcome to the bookstore")
print("What book do you want?")

print("[1] Lord of the rings - [2] Violet evergarden [3] Lord of the flies ")

# book_choice = int(input("input book")) #string
# print(book_choice)
# Out:
# Welcome to the bookstore
# What book do you want?
# [1] Lord of the rings - [2] Violet evergarden [3] Lord of the flies
